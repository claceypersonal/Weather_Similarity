# %%
from tinydb import TinyDB, Query

# %%
db = TinyDB('db.json')

# %%
User = Query()

# %%
db.search(User.city.member.memName == 'Romania')
# Out:
# [{'city': {'lang': 'en',
#    'cityName': 'Arad',
#    'cityLatitude': '46.133611000',
#    'cityLongitude': '21.353611000',
#    'cityId': 2089,
#    'isCapital': False,
#    'stationName': 'Arad',
#    'tourismURL': '',
#    'tourismBoardName': '',
#    'isDep': False,
#    'timeZone': '+0200',
#    'isDST': 'N',
#    'member': {'memId': 183,
#     'memName': 'Romania',
#     'shortMemName': '',
#     'url': 'www.inmh.ro',
#     'orgName': 'National Meteorological Administration',
#     'logo': 'romania_logo.png',
#     'ra': 6},
#    'forecast': {'issueDate': '2024-01-29 14:11:07',
#     'timeZone': 'Local',
#     'forecastDay': [{'forecastDate': '2024-01-30',
#       'wxdesc': '',
#       'weather': 'Partly Bright',
#       'minTemp': '-5',
#       'maxTemp': '5',
#       'minTempF': '23',
#       'maxTempF': '41',
#       'weatherIcon': 2203},
#      {'forecastDate': '2024-01-31',
#       'wxdesc': '',
#       'weather': 'Partly Bright',
#       'minTemp': '-4',
# ...
