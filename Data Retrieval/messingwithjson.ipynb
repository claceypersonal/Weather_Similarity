# %%
import json
import os
import re

# %%
with open('CITYJSON/Wuhan.json', 'r') as read_file:
    data = json.load(read_file)

# %%
for filename in os.listdir("CITYJSON/"):
    if filename.endswith(".json"): 
        with open("CITYJSON/" + filename, 'r') as read_file:
            data = json.load(read_file)
            print(filename)
            print(data[0]['name'])
            data_str = str(data)
            k = data_str.find('°') - 2
            print(data_str[k:k+19])
        continue
    else:
        continue
# Out:
# Wuhan.json
# Wuhan
# 7 °C. Ang kinainita
# Dongguan.json
# Dongguan
# 22°56′39″N 113°54′4
# Hrodna.json
# Grodno
# 53°41′18″N 23°49′33
# Toulouse.json
# Toulouse
# 43°36′16″N 1°26′38″
# Yongzhou.json
# Yongzhou
# 9 °C. Ang kinainita
# Jieyang.json
# Jieyang
# 23°32′30″N 116°21′5
# İzmir.json
# İzmir
# 38°27′44″N 27°05′32
# Abaetetuba.json
# Abaetetuba
#  1°43′05″S 48°52′57
# Odessa.json
# Odessa, Texas
# 31°51′48″N 102°21′5
# Ciudad Bolívar.json
# Ciudad Bolívar
#  5°51′14″N 76°01′31
# Lamitan.json
# Lamitan
#  6°39′N 122°08′E /
# Southampton.json
# Southampton
# 32°15′03″N 64°51′23
# Kansas City772.json
# Kansas City, Missouri
# 39°06′35″N 94°35′19
# Kawanishi.json
# Kawanishi, Hyōgo
# 34°50′N 135°25′Ö /
# Denizli.json
# Denizli
# 37°50′25″N 29°04′11
# Putian.json
# Putian
#  7°52′34″N 124°26′0
# Sekondi-Takoradi.json
# Sekondi-Takoradi
# 04°55′00″N 01°46′00
# Nizhny Novgorod.json
# Nizhny Novgorod
# 56°19′37″N 44°00′27
# Aleppo.json
# Aleppo
# 36°15′00″N 37°37′00
# ...

# %%
data_str = str(data)
data[0]['name']
# Out:
# 'Wuhan'

# %%
data_str.find('°')
#data_str[7319:7338]
# Out:
# 7321
